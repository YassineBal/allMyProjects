# %% [markdown]
# # <center> Evaluate ML Algorithms With Resampling Techinique </center>

# %%
# Import libraries
import warnings
warnings.filterwarnings('ignore')
from pandas import read_csv
# Machine Learning Module
from sklearn.model_selection import train_test_split
# Machine Learning Algorithm (classifier, model)
from sklearn.linear_model import LogisticRegression
filename = './datasets/pima-indians-diabetes.data.csv'
col_names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
data = read_csv(filename, names=col_names)

# %% [markdown]
# ## I. Train and Test Split

# %%
# Get values from dataframe
array = data.values
# Get inputs (all variables except the class)
X = array[ : , 0:-1]
# Get the output (class)
Y = array[ : , -1]
test_proportion = 0.30
seed = 7 # Controler le fait aleatoire dans la division de donnees
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = test_proportion
                                                    , random_state = seed)
# Training
model = LogisticRegression(solver='newton-cg')
model.fit(X_train, Y_train)
print("Training completed successfully!")
result = model.score(X_test, Y_test)
print('Accuracy : %.3f%%' % (result*100))
print('Manual evaluation\n-----------------')
Y_predicted = model.predict(X_test)
Y_proba = model.predict_proba(X_test)
TP = TN = FP = FN = 0
for reel, predict, proba in zip(Y_test, Y_predicted, Y_proba):
    if reel == 1.0 and predict == 1.0:
        TP += 1
    elif reel == 1.0 and predict == 0.0:
        FN += 1
    elif reel == 0.0 and predict == 0.0:
        TN += 1
    elif reel == 0.0 and predict == 1.0:
        FP += 1
    print(f'Reel: {reel} | Predicted: {predict} | > Probaility: {proba}')
Acc = ((TP+TN)/(TP+TN+FP+FN))*100
print(f'Manual Accuracy: {Acc}')
# Out:
# Training completed successfully!
# Accuracy : 77.922%
# Manual evaluation
# -----------------
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.93286382 0.06713618]
# Reel: 1.0 | Predicted: 1.0 | > Probaility: [0.1224743 0.8775257]
# Reel: 1.0 | Predicted: 1.0 | > Probaility: [0.24880202 0.75119798]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.85500372 0.14499628]
# Reel: 1.0 | Predicted: 0.0 | > Probaility: [0.62185733 0.37814267]
# Reel: 1.0 | Predicted: 0.0 | > Probaility: [0.50296573 0.49703427]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.92790713 0.07209287]
# Reel: 1.0 | Predicted: 0.0 | > Probaility: [0.72737007 0.27262993]
# Reel: 0.0 | Predicted: 1.0 | > Probaility: [0.0594588 0.9405412]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.86946249 0.13053751]
# Reel: 1.0 | Predicted: 1.0 | > Probaility: [0.16048137 0.83951863]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.89622661 0.10377339]
# Reel: 0.0 | Predicted: 1.0 | > Probaility: [0.28553362 0.71446638]
# Reel: 1.0 | Predicted: 1.0 | > Probaility: [0.14549326 0.85450674]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.53863686 0.46136314]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.80365894 0.19634106]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.72009133 0.27990867]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.85694554 0.14305446]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.86567641 0.13432359]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.85248463 0.14751537]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.52744443 0.47255557]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.73812675 0.26187325]
# Reel: 1.0 | Predicted: 1.0 | > Probaility: [0.17688689 0.82311311]
# Reel: 1.0 | Predicted: 1.0 | > Probaility: [0.39460131 0.60539869]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.81880276 0.18119724]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.82258194 0.17741806]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.92135443 0.07864557]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.51345333 0.48654667]
# Reel: 1.0 | Predicted: 0.0 | > Probaility: [0.75633425 0.24366575]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.6871342 0.3128658]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.55231505 0.44768495]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.72598284 0.27401716]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.86906192 0.13093808]
# Reel: 1.0 | Predicted: 1.0 | > Probaility: [0.33391706 0.66608294]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.96675658 0.03324342]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.86768967 0.13231033]
# Reel: 1.0 | Predicted: 0.0 | > Probaility: [0.73105919 0.26894081]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.85042857 0.14957143]
# Reel: 1.0 | Predicted: 1.0 | > Probaility: [0.33819334 0.66180666]
# Reel: 1.0 | Predicted: 1.0 | > Probaility: [0.27186753 0.72813247]
# Reel: 1.0 | Predicted: 1.0 | > Probaility: [0.33446951 0.66553049]
# Reel: 1.0 | Predicted: 1.0 | > Probaility: [0.36542507 0.63457493]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.7572109 0.2427891]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.97448188 0.02551812]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.73771154 0.26228846]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.88484195 0.11515805]
# Reel: 1.0 | Predicted: 0.0 | > Probaility: [0.53503603 0.46496397]
# Reel: 1.0 | Predicted: 0.0 | > Probaility: [0.71657383 0.28342617]
# Reel: 1.0 | Predicted: 1.0 | > Probaility: [0.40324276 0.59675724]
# Reel: 1.0 | Predicted: 1.0 | > Probaility: [0.07746951 0.92253049]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.82017183 0.17982817]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.89451855 0.10548145]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.65916958 0.34083042]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0

# Reel: 1.0 | Predicted: 1.0 | > Probaility: [0.22598164 0.77401836]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.715706 0.284294]
# Reel: 1.0 | Predicted: 0.0 | > Probaility: [0.67638347 0.32361653]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.53777139 0.46222861]
# Reel: 0.0 | Predicted: 1.0 | > Probaility: [0.48136914 0.51863086]
# Reel: 1.0 | Predicted: 1.0 | > Probaility: [0.45804912 0.54195088]
# Reel: 1.0 | Predicted: 1.0 | > Probaility: [0.47498549 0.52501451]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.59160578 0.40839422]
# Reel: 0.0 | Predicted: 1.0 | > Probaility: [0.38712245 0.61287755]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.88110891 0.11889109]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.91368814 0.08631186]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.91066772 0.08933228]
# Reel: 1.0 | Predicted: 0.0 | > Probaility: [0.70573726 0.29426274]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.77679497 0.22320503]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.92830211 0.07169789]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.96812741 0.03187259]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.95405753 0.04594247]
# Reel: 0.0 | Predicted: 1.0 | > Probaility: [0.12811928 0.87188072]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.54802161 0.45197839]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.60929753 0.39070247]
# Reel: 1.0 | Predicted: 1.0 | > Probaility: [0.07999645 0.92000355]
# Reel: 1.0 | Predicted: 1.0 | > Probaility: [0.24755516 0.75244484]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.57925428 0.42074572]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.67623652 0.32376348]
# Reel: 0.0 | Predicted: 1.0 | > Probaility: [0.35310406 0.64689594]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.98232063 0.01767937]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.95786751 0.04213249]
# Reel: 1.0 | Predicted: 1.0 | > Probaility: [0.46516081 0.53483919]
# Reel: 0.0 | Predicted: 1.0 | > Probaility: [0.49006169 0.50993831]
# Reel: 1.0 | Predicted: 1.0 | > Probaility: [0.49104853 0.50895147]
# Reel: 0.0 | Predicted: 1.0 | > Probaility: [0.06969318 0.93030682]
# Reel: 0.0 | Predicted: 1.0 | > Probaility: [0.26856152 0.73143848]
# Reel: 1.0 | Predicted: 0.0 | > Probaility: [0.54618728 0.45381272]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.88076136 0.11923864]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.58848886 0.41151114]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.92857356 0.07142644]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.72901024 0.27098976]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.96671291 0.03328709]
# Reel: 1.0 | Predicted: 1.0 | > Probaility: [0.33161066 0.66838934]
# Reel: 1.0 | Predicted: 1.0 | > Probaility: [0.28452321 0.71547679]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.91771883 0.08228117]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.6555599 0.3444401]
# Reel: 1.0 | Predicted: 0.0 | > Probaility: [0.59511689 0.40488311]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.9458038 0.0541962]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.5764577 0.4235423]
# Reel: 1.0 | Predicted: 1.0 | > Probaility: [0.02357071 0.97642929]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.95839605 0.04160395]
# Reel: 1.0 | Predicted: 0.0 | > Probaility: [0.52187479 0.47812521]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.97769015 0.02230985]
# Reel: 0.0 | Predicted: 1.0 | > Probaility: [0.36981878 0.63018122]
# Reel: 1.0 | Predicted: 1.0 | > Probaility: [0.35385699 0.64614301]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.67059816 0.32940184]
# Reel: 1.0 | Predicted: 0.0 | > Probaility: [0.70209613 0.29790387]
# Reel: 0.0 | Predicted: 1.0 | > Probaility: [0.33272132 0.66727868]
# Reel: 1.0 | Predicted: 0.0 | > Probaility: [0.73809977 0.26190023]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.71118829 0.28881171]
# Reel: 1.0 | Predicted: 1.0 | > Probaility: [0.09924946 0.90075054]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.88351441 0.11648559]
# Reel: 0.0 | Predicted: 0.0 | > Probaility: [0.86325215 0.13674785]
# Manual Accuracy: 77.92207792207793

# %% [markdown]
# ## II. K-fold Cross Validation

# %%
from sklearn.model_selection import KFold, cross_val_score
# Define kfold configuration
num_fold = 17
seed = 10
kfold = KFold(n_splits=num_fold, random_state=seed, shuffle=True)
model = LogisticRegression(solver='newton-cg')
results = cross_val_score(model, X, Y, cv=kfold)
print("Accuracy: %.3f%% (%.3f%%)" % (results.mean()*100.0, results.std()*100.0))
# Out:
# Accuracy: 77.477% (6.377%)

# %% [markdown]
# ## III. Leave-One-Out Cross Validation

# %%
from sklearn.model_selection import LeaveOneOut, cross_val_score
loocv = LeaveOneOut()
model = LogisticRegression()
results = cross_val_score(model, X, Y, cv=loocv)
print("Accuracy: %.3f%% (%.3f%%)" % (results.mean()*100.0, results.std()*100.0))
# Out:
# Accuracy: 77.865% (41.516%)

# %% [markdown]
# ## IV. Repeated Random Train-test Split

# %%
from sklearn.model_selection import ShuffleSplit, cross_val_score
test_proportion = 0.30
seed = 7
num_fold = 100000
kflod = ShuffleSplit(n_splits=num_fold, test_size= test_proportion, random_state=seed)
model = LogisticRegression()
results = cross_val_score(model, X, Y, cv=kflod)
print("Accuracy: %.3f%% (%.3f%%)" % (results.mean()*100.0, results.std()*100.0))
# Out:
# Accuracy: 76.897% (2.435%)
